# %%
import numpy as np
import pandas as pd
from numpy.random import randn

from scipy import stats

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
dataset = randn(100)

# %%
sns.distplot(dataset,bins = 25)
# histogram and density estimate plot combined
# Out:
# C:\Users\Bingxin\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(dataset,bins =25, rug=True, hist = False)
# rug shown, histogram no longer

# %%
# Controlling plot parameters individually
sns.distplot(dataset, bins = 25,
            kde_kws ={'color':'indianred','label':'KDE PLOT'},
            hist_kws ={'color':'blue','label':'HIST'})
# Out:
# C:\Users\Bingxin\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
from pandas import Series

# %%
ser1 = Series(dataset,name = 'My_data')
ser1
# Out:
# 0    -0.953242
# 1     0.064287
# 2    -0.226010
# 3    -0.762308
# 4     0.279652
# 5     1.096797
# 6    -0.311575
# 7    -1.078645
# 8    -1.676952
# 9    -0.392952
# 10    0.494939
# 11    0.217068
# 12    0.801761
# 13    1.791537
# 14    0.081009
# 15   -1.410079
# 16    0.084073
# 17   -0.295860
# 18    0.436649
# 19    0.202713
# 20    1.052538
# 21    0.083191
# 22   -0.082495
# 23    1.147809
# 24   -1.100849
# 25    0.868027
# 26    0.816506
# 27   -1.381832
# 28    1.641695
# 29   -0.230731
#         ...
# 70    0.096554
# 71   -0.917347
# 72    0.072562
# 73    1.927932
# 74   -0.077219
# 75   -0.408522
# 76   -0.115889
# 77    0.393164
# 78    1.017602
# 79    0.023320
# 80   -0.049769
# 81    0.115717
# 82    0.021790
# 83    2.791614
# 84   -0.267486
# 85    0.225467
# 86   -0.442285
# 87   -0.920089
# 88   -0.838557
# 89   -1.003101
# 90   -1.300906
# 91    0.207272
# 92    0.669328
# 93    0.601032
# 94   -0.357459
# 95   -0.464584
# 96   -1.392242
# 97    1.246071
# 98    0.040646
# 99    0.569914
# Name: My_data, Length: 100, dtype: float64

# %%
sns.distplot(ser1,bins = 25)
# Out:
# C:\Users\Bingxin\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
# searbon work really well with pandas
