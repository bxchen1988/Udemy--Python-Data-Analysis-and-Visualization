# %%
# standard import
import numpy as np
import pandas as pd
from numpy.random import randn

# %%
# stats 
from scipy import stats

# %%
# plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline 
# see plot result from notebook

# %%
dataset1 = randn(100)

# %%
plt.hist(dataset1)
# Out:
# (array([ 4.,  4., 10., 11., 23., 18., 16.,  9.,  4.,  1.]),
#  array([-2.4586677 , -1.96974632, -1.48082495, -0.99190357, -0.50298219,
#         -0.01406082,  0.47486056,  0.96378193,  1.45270331,  1.94162468,
#          2.43054606]),
#  <a list of 10 Patch objects>)

# %%
dataset2 =randn(80)

# %%
plt.hist(dataset2, color = 'indianred')
# Out:
# (array([ 3.,  8.,  7., 11., 17., 13.,  9.,  6.,  3.,  3.]),
#  array([-1.99283851, -1.55484228, -1.11684606, -0.67884983, -0.2408536 ,
#          0.19714262,  0.63513885,  1.07313508,  1.5111313 ,  1.94912753,
#          2.38712376]),
#  <a list of 10 Patch objects>)

# %%
# overlay histograms
plt.hist(dataset1,density= True, # normalizing y axis to be between 0 and 1
         color = 'Indianred',
         alpha = 0.5, #transparency
        bins = 20)
plt.hist(dataset2,density = True, alpha = 0.5, bins = 20)
# Out:
# (array([0.11415623, 0.05707812, 0.17123435, 0.28539059, 0.22831247,
#         0.17123435, 0.22831247, 0.39954682, 0.45662494, 0.51370306,
#         0.3424687 , 0.39954682, 0.22831247, 0.28539059, 0.05707812,
#         0.28539059, 0.05707812, 0.11415623, 0.05707812, 0.11415623]),
#  array([-1.99283851, -1.7738404 , -1.55484228, -1.33584417, -1.11684606,
#         -0.89784794, -0.67884983, -0.45985172, -0.2408536 , -0.02185549,
#          0.19714262,  0.41614074,  0.63513885,  0.85413696,  1.07313508,
#          1.29213319,  1.5111313 ,  1.73012942,  1.94912753,  2.16812565,
#          2.38712376]),
#  <a list of 20 Patch objects>)

# %%
data1 = randn(1000)
data2 = randn(1000)

# %%
sns.jointplot(data1,data2)
# Out:
# C:\Users\Bingxin\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Bingxin\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
# more concise
sns.jointplot(data1,data2,kind ='hex')
# Out:
# C:\Users\Bingxin\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Bingxin\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
