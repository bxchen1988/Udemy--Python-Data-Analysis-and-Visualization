# %%
import pandas as pd
import os
import numpy as np
from pandas import Series,DataFrame

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Bingxin\\Anaconda2\\Udemy - Python Data Visualization and Machine Learning'

# %%
os.chdir("C:\Users\Bingxin\Anaconda2")

# %%
xlsxfile = pd.ExcelFile('diff.xlsx')

# %%
xlsxfile

# %%
diff_df = xlsxfile.parse('Sheet1')

# %%
diff_df.head()
# Out:
#    diff  citationFlow  trustFlow  facebookShares  externalBackLinks  \
# 0    86            49         23           50379               2058
# 1    85            45         26               0              13571
# 2    84            51         69             737              85087
# 3    83            50         65              62              52596
# 4    83            67         67             380               5006
#
#    refDomains  refIPs
# 0         406     386
# 1        1890    1697
# 2        2813    1264
# 3         904     838
# 4         552     318

# %%
diff_df.describe()
# Out:
#               diff  citationFlow    trustFlow  facebookShares  \
# count  2990.000000   2990.000000  2990.000000     2990.000000
# mean     43.355853     27.220067    19.725418     1909.594983
# std      15.987024     13.575818    15.642091    24879.210142
# min       5.000000      1.000000     0.000000        0.000000
# 25%      31.000000     16.000000     8.000000        0.000000
# 50%      44.000000     28.000000    18.000000        5.500000
# 75%      56.000000     37.000000    28.000000      147.000000
# max      86.000000     80.000000    85.000000   819199.000000
#
#        externalBackLinks     refDomains        refIPs
# count       2.990000e+03    2990.000000   2990.000000
# mean        1.699416e+04     187.629097     96.453512
# std         3.221987e+05    2166.490682   1015.294890
# min         0.000000e+00       0.000000      0.000000
# 25%         1.000000e+00       1.000000      1.000000
# 50%         2.400000e+01       7.000000      7.000000
# ...

# %%
diff_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2990 entries, 0 to 2989
# Data columns (total 7 columns):
# diff                 2990 non-null int64
# citationFlow         2990 non-null int64
# trustFlow            2990 non-null int64
# facebookShares       2990 non-null int64
# externalBackLinks    2990 non-null int64
# refDomains           2990 non-null int64
# refIPs               2990 non-null int64
# dtypes: int64(7)
# memory usage: 163.6 KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
diff_df['diff'].hist(bins = 80)

# %%
sns.jointplot(diff_df['diff'],diff_df['citationFlow'])
# Out:
# C:\Users\Bingxin\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Bingxin\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.pairplot(diff_df)
